# %%
import pandas as pd
import sns

# %%
df = pd.read_csv('../data/raw/raw.csv')
df
# Out:
#                      date  ave_flot_air_flow  ave_flot_level  iron_feed  \
# 0     2017-04-24 00:00:00         300.263166      383.982443      55.17
# 1     2017-04-24 01:00:00         299.782402      386.049069      55.17
# 2     2017-04-24 02:00:00         299.750052      385.250935      55.17
# 3     2017-04-24 03:00:00         299.997522      389.635519      55.17
# 4     2017-04-24 04:00:00         300.005220      387.810807      55.17
# ...                   ...                ...             ...        ...
# 1812  2017-08-27 10:00:00         299.958702      466.646630      60.02
# 1813  2017-08-27 11:00:00         300.013584      468.726893      60.02
# 1814  2017-08-27 12:00:00         300.127863      490.918520      60.02
# 1815  2017-08-29 22:00:00         299.670466      445.903411      54.49
# 1816  2017-09-08 15:00:00         299.883469      400.304983      59.39
#
#       starch_flow  amina_flow  ore_pulp_flow  ore_pulp_pH  ore_pulp_density  \
# 0     1979.589150  599.676489     400.017222     9.774028          1.753206
# 1     1758.466329  600.043100     400.484528     9.539246          1.754190
# 2     2379.752428  599.948406     400.325617     9.434227          1.756873
# 3     2287.130046  599.580383     399.801506     9.725607          1.727125
# 4     2291.789167  599.871217     399.567333     9.845198          1.633063
# ...           ...         ...            ...          ...               ...
# 1812  3191.856167  319.003256     402.920396     9.294575          1.559673
# 1813  3460.924500  393.149528     397.119469     9.393422          1.696894
# 1814  3382.668556  430.495100     400.424371     9.367542          1.721010
# 1815  2778.946000  563.556606     398.260061     8.844935          1.689140
# 1816  3846.087611  438.641939     401.070041     9.399870          1.605821
#
#       silica_concentrate
# 0               4.360000
# 1               3.290000
# 2               4.900000
# 3               4.860153
# 4               4.780898
# ...                  ...
# 1812            1.690000
# 1813            1.590000
# 1814            1.450000
# 1815            2.970000
# 1816            1.840000
#
# [1817 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
numeric_cols = df.select_dtypes(include='float64').columns
df_num = df[numeric_cols]
corr_matrix = df_num.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x=df_num['amina_flow'], y=df_num['silica_concentrate'], data=df_num)

plt.xlabel('amina_flow')
plt.ylabel('silica_concentrate')

plt.show()
